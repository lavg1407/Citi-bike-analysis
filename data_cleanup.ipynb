# %%
# dependencies
import random
import pandas as pd
import requests
import json
import numpy as np
import glob
import json

# %%
# combine all citi bikeshare csv into one csv

path = "raw_data"
all_files = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
timeYr = []

for file_ in all_files:
    df = pd.read_csv(file_,index_col=None, header=0)
    timeYr.append(df)
frame = pd.concat(timeYr)
frame.to_csv("raw_data/data_merged.csv", index=False)

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1           572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2           387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3           188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4           594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3640     Journal Square               40.733670
# 2              3640     Journal Square               40.733670
# 3              3186      Grove St PATH               40.719586
# 4              3212    Christ Hospital               40.734786
#
#    start station longitude  end station id end station name  \
# 0               -74.033759            3199     Newport Pkwy
# ...

# %%
df.count()
# Out:
# tripduration               11694
# starttime                  11694
# stoptime                   11694
# start station id           11694
# start station name         11694
# start station latitude     11694
# start station longitude    11694
# end station id             11694
# end station name           11694
# end station latitude       11694
# end station longitude      11694
# bikeid                     11694
# usertype                   11694
# birth year                 11694
# gender                     11694
# dtype: int64

# %%
df['Year'] = df["stoptime"].str[:4]
df['Month'] = df['stoptime'].str[5:7]
df['Date'] = df["stoptime"].str[:10]
df['Time_Hr'] = df["stoptime"].str[11:13]
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1           572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2           387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3           188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4           594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3640     Journal Square               40.733670
# 2              3640     Journal Square               40.733670
# 3              3186      Grove St PATH               40.719586
# 4              3212    Christ Hospital               40.734786
#
#    start station longitude  end station id end station name  \
# 0               -74.033759            3199     Newport Pkwy
# ...

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender', 'Year', 'Month', 'Date', 'Time_Hr'],
#       dtype='object')

# %%
df.count()
# Out:
# tripduration               11694
# starttime                  11694
# stoptime                   11694
# start station id           11694
# start station name         11694
# start station latitude     11694
# start station longitude    11694
# end station id             11694
# end station name           11694
# end station latitude       11694
# end station longitude      11694
# bikeid                     11694
# usertype                   11694
# birth year                 11694
# gender                     11694
# Year                       11694
# Month                      11694
# Date                       11694
# Time_Hr                    11694
# dtype: int64
